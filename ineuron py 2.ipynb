# %% [markdown]
# Create the pattern using nested for loop in Python

# %%
for i in range(0, 5):  
    for j in range(0, i + 1):  
        print("*", end=' ')  
    print(" ")  
for i in range(4+ 1, 0, -1):  
    for j in range(0, i - 1):  
        print("*", end=' ')  
    print(" ")
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %% [markdown]
# Write a Python program to reverse a word after accepting the input from the user.

# %%
word=input("Give a name to reverse :  ")
rev_word=word[::-1]
print(rev_word)
# Out:
# Give a name to reverse :  shruthi
# ihturhs
